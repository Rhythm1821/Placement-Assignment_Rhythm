# %%
import pandas as pd
import requests

# %%
url = 'http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes'
response=requests.get(url)
data=response.json()

# %%
df=pd.DataFrame(data['_embedded']['episodes'])
df.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
#
#    runtime          rating                                              image  \
# 0       68  {'average': 8}  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  <p>A woman named Dolores is a free spirit in t...
#
#                                               _links
# 0  {'self': {'href': 'https://api.tvmaze.com/epis...

# %%
# Dropping airstamp because it is not asked in the question
df.drop(columns=['airstamp'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       36 non-null     int64
#  1   url      36 non-null     object
#  2   name     36 non-null     object
#  3   season   36 non-null     int64
#  4   number   36 non-null     int64
#  5   type     36 non-null     object
#  6   airdate  36 non-null     object
#  7   airtime  36 non-null     object
#  8   runtime  36 non-null     int64
#  9   rating   36 non-null     object
#  10  image    36 non-null     object
#  11  summary  36 non-null     object
#  12  _links   36 non-null     object
# dtypes: int64(4), object(9)
# memory usage: 3.8+ KB

# %%
# Converting dict to float
df['rating']=df['rating'].apply(lambda x:list(x.values())[0])

# %%
# object to datetime format
df['airdate']=pd.to_datetime(df['airdate'])
df['airtime']=pd.to_datetime(df['airtime']).dt.strftime('%I:%M')

# %%
df['summary'] = df['summary'].str.replace(r'<[^<>]*>', '', regex=True)

# %%
df.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type    airdate airtime  runtime  \
# 0       The Original       1       1  regular 2016-10-02   09:00       68
# 1           Chestnut       1       2  regular 2016-10-09   09:00       60
# 2          The Stray       1       3  regular 2016-10-16   09:00       60
# 3  Dissonance Theory       1       4  regular 2016-10-23   09:00       60
# 4        Contrapasso       1       5  regular 2016-10-30   09:00       60
#
#    rating                                              image  \
# 0     8.0  {'medium': 'https://static.tvmaze.com/uploads/...
# 1     7.7  {'medium': 'https://static.tvmaze.com/uploads/...
# 2     7.6  {'medium': 'https://static.tvmaze.com/uploads/...
# 3     7.9  {'medium': 'https://static.tvmaze.com/uploads/...
# 4     8.0  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  A woman named Dolores is a free spirit in the ...
# 1  Bernard suspects that someone is sabotaging th...
# 2  Bernard continues to investigate Dolores' supp...
# 3  While Dolores joins William and Logan on their...
# 4  Dolores takes the first step on her path of di...
#
#                                               _links
# 0  {'self': {'href': 'https://api.tvmaze.com/epis...
# 1  {'self': {'href': 'https://api.tvmaze.com/epis...
# 2  {'self': {'href': 'https://api.tvmaze.com/epis...
# 3  {'self': {'href': 'https://api.tvmaze.com/epis...
# 4  {'self': {'href': 'https://api.tvmaze.com/epis...
